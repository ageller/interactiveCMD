# %% [markdown]
# # Testing the Bokeh script

# %%
from bokeh.plotting import *

# %%
# %load_ext autoreload
# %autoreload 2

from interactiveCMD import createInteractive

# %%
output_notebook() # run in the notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
layout = createInteractive('ngc188.phot')

# in order to run a Python callback in a Jupyter notbook, you need to include the following
def bkapp(doc):
    doc.add_root(layout)

show(bkapp)
# Out:
# <script id="1069">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:51383/autoload.js?bokeh-autoload-element=1069&bokeh-absolute-url=http://localhost:51383&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %% [markdown]
# ## Check

# %%
from astropy.io import ascii

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tbl = ascii.read('ngc188.phot.new')
f,ax  = plt.subplots(figsize = (5,8))
ax.scatter(tbl['G_BP'] - tbl['G_RP'], tbl['G'], color='gray')
singles = tbl[tbl['useDBI'] == 1]
ax.scatter(singles['G_BP'] - singles['G_RP'], singles['G'], color='royalblue')

ax.set_xlim([0.5, 2])
ax.set_ylim([20, 10])
# Out:
# (20.0, 10.0)
